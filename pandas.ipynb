# %%
import pandas as pd

# %%
data={
    'Name':['Alice','bob','charlie'],
    'age':[25,56,35],
    'city':['new york','los angels','chicago']
}
data
# Out:
# {'Name': ['Alice', 'bob', 'charlie'],
#  'age': [25, 56, 35],
#  'city': ['new york', 'los angels', 'chicago']}

# %%
df=pd.DataFrame(data)
df
# Out:
#       Name  age        city
# 0    Alice   25    new york
# 1      bob   56  los angels
# 2  charlie   35     chicago

# %%
df[['Name','age']] ## selecting multiple columns from the dataframe
# Out:
#       Name  age
# 0    Alice   25
# 1      bob   56
# 2  charlie   35

# %%
df.loc[1]  ##selecting a single row from the dataframe using loc
# Out:
# Name           bob
# age             56
# city    los angels
# Name: 1, dtype: object

# %%
df.iloc[1] ##electing a single row from the dataframe using iloc
# Out:
# Name           bob
# age             56
# city    los angels
# Name: 1, dtype: object

# %% [markdown]
# # # setting individual columns as a index

# %%
# df.set_index('Name',inplace=True) 
# df

# %% [markdown]
# ### setting new data as index

# %%
df.index=['a','b','c']
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='str')

# %%
df.iloc[1] ##position
# Out:
# Name          bob
# NAME_UPPER    BOB
# Name: b, dtype: str

# %%
df.loc['b'] ##labels
# Out:
# Name          bob
# NAME_UPPER    BOB
# Name: b, dtype: str

# %%
del df['city']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\nikhi\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df=df.drop(['age'],axis=1)
df
# Out:
#       Name
# a    Alice
# b      bob
# c  charlie

# %%
new_column={
    'Name':'Name',
    'Age':'Age'
}
df.rename(columns=new_column,inplace=True)
df
# Out:
#       Name
# a    Alice
# b      bob
# c  charlie

# %%
uppercase_values=df['Name'].str.upper()
uppercase_values
# Out:
# a      ALICE
# b        BOB
# c    CHARLIE
# Name: Name, dtype: str

# %%
df['NAME_UPPER']=df['Name'].str.upper()
df
# Out:
#       Name NAME_UPPER
# a    Alice      ALICE
# b      bob        BOB
# c  charlie    CHARLIE

# %% [markdown]
# ## performing data Anlaysis over some Random Data

# %% [markdown]
# CSV Datafile

# %%
data =pd.read_csv('data.csv') ## reading a csv file into a dataframe using the read_csv method
data
# Out:
#       Name   Age         City    Position
# 0    Alice  30.0     New York     Manager
# 1      Bob  25.0  Los Angeles   Developer
# 2  Charlie   NaN      Chicago     Analyst
# 3    David  28.0      Houston    Designer
# 4      Eve  32.0      Phoenix  Consultant

# %%
data.isnull().sum()
# Out:
# Name        0
# Age         1
# City        0
# Position    0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Name        5
# Age         4
# City        5
# Position    5
# dtype: int64

# %% [markdown]
# dropping the rows which has null values

# %%
data.dropna()
# Out:
#     Name   Age         City    Position
# 0  Alice  30.0     New York     Manager
# 1    Bob  25.0  Los Angeles   Developer
# 3  David  28.0      Houston    Designer
# 4    Eve  32.0      Phoenix  Consultant

# %% [markdown]
# dropping the coilumns which has null values

# %%
data.dropna(axis=1)
# Out:
#       Name         City    Position
# 0    Alice     New York     Manager
# 1      Bob  Los Angeles   Developer
# 2  Charlie      Chicago     Analyst
# 3    David      Houston    Designer
# 4      Eve      Phoenix  Consultant

# %%
data
# Out:
#       Name   Age         City    Position
# 0    Alice  30.0     New York     Manager
# 1      Bob  25.0  Los Angeles   Developer
# 2  Charlie   NaN      Chicago     Analyst
# 3    David  28.0      Houston    Designer
# 4      Eve  32.0      Phoenix  Consultant

# %% [markdown]
# Instead of dropping just fill the full values with actual values

# %%
data.fillna(0,inplace=True)
# Out:
#       Name   Age         City    Position
# 0    Alice  30.0     New York     Manager
# 1      Bob  25.0  Los Angeles   Developer
# 2  Charlie   0.0      Chicago     Analyst
# 3    David  28.0      Houston    Designer
# 4      Eve  32.0      Phoenix  Consultant

# %%
data.fillna(data['Age'].mean(),inplace=True)
data
# Out:
#       Name   Age         City    Position
# 0    Alice  30.0     New York     Manager
# 1      Bob  25.0  Los Angeles   Developer
# 2  Charlie   0.0      Chicago     Analyst
# 3    David  28.0      Houston    Designer
# 4      Eve  32.0      Phoenix  Consultant

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5 non-null      str
#  1   Age       5 non-null      float64
#  2   City      5 non-null      str
#  3   Position  5 non-null      str
# dtypes: float64(1), str(3)
# memory usage: 292.0 bytes

# %%
data.describe()
# Out:
#              Age
# count   5.000000
# mean   23.000000
# std    13.114877
# min     0.000000
# 25%    25.000000
# 50%    28.000000
# 75%    30.000000
# max    32.000000

# %%
data.head()
# Out:
#       Name   Age         City    Position
# 0    Alice  30.0     New York     Manager
# 1      Bob  25.0  Los Angeles   Developer
# 2  Charlie   0.0      Chicago     Analyst
# 3    David  28.0      Houston    Designer
# 4      Eve  32.0      Phoenix  Consultant

# %%
data.tail()
# Out:
#       Name   Age         City    Position
# 0    Alice  30.0     New York     Manager
# 1      Bob  25.0  Los Angeles   Developer
# 2  Charlie   0.0      Chicago     Analyst
# 3    David  28.0      Houston    Designer
# 4      Eve  32.0      Phoenix  Consultant
